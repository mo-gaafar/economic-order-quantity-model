# %%
import math
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Define EOQ function


def EOQ(S, D, H):
    """
    Economic Order Quantity
    
    Arguments:
    S: ordering cost
    D: annual quantity demanded
    H: holding cost per unit
    
    Returns:
    [Q, number_of_orders, time_between_cycles, annual ordering cost, annual holding cost, annual total cost]
    
    """

    # Validate that all function arguments are non-negative
    if (S > 0 and D > 0 and H > 0):

        Q = (np.sqrt(2*S*D/H))
        number_of_orders = D/Q
        time_between_cycles = 12/number_of_orders
        AOC = D/Q*S
        AHC = Q/2*H
        ATC = AOC+AHC

        return [Q, number_of_orders, time_between_cycles, AOC, AHC, ATC]

    else:
        print("Error. All function arguments must be non-negative.")

# %%
### ECONOMIC ORDER QUANTITY ###


# Run example
EOQ(10, 2400, 0.3)

# Create period list and append values
period = [0, 2]
while period[-1] < 12:
    period.append(period[-1])
    period.append(period[-1]+2)

# Create inventory list and append values
inventory = [400, 0]
while len(inventory) < len(period):
    inventory.append(400)
    inventory.append(0)

# Plot inventory level graph
plt.figure(figsize=(15, 5))
plt.plot(period, inventory)
plt.xlabel("Month")
plt.ylabel("Inventory Level")
plt.title("Economic Order Quantity")
# Out:
# Text(0.5, 1.0, 'Economic Order Quantity')

# %%
# def calculate_eoq(demand, ordering_cost, holding_cost):
#     """
#     Calculate Economic Order Quantity (EOQ) based on the given parameters.

#     Parameters:
#     - demand: Annual demand for the product.
#     - ordering_cost: Cost per order (ordering/setup cost).
#     - holding_cost: Holding cost per unit per year.

#     Returns:
#     - eoq: Economic Order Quantity.
#     """
#     eoq = math.sqrt((2 * demand * ordering_cost) / holding_cost)
#     return eoq

# def calculate_total_cost(eoq, demand, ordering_cost, holding_cost):
#     """
#     Calculate the total cost associated with the given EOQ.

#     Parameters:
#     - eoq: Economic Order Quantity.
#     - demand: Annual demand for the product.
#     - ordering_cost: Cost per order (ordering/setup cost).
#     - holding_cost: Holding cost per unit per year.

#     Returns:
#     - total_cost: Total cost associated with the given EOQ.
#     """
#     ordering_cost_total = (demand / eoq) * ordering_cost
#     holding_cost_total = (eoq / 2) * holding_cost
#     total_cost = ordering_cost_total + holding_cost_total
#     return total_cost

# # Example usage:
# demand = 1000  # Annual demand
# ordering_cost = 50  # Cost per order
# holding_cost = 2  # Holding cost per unit per year

# # Calculate EOQ
# eoq_result = calculate_eoq(demand, ordering_cost, holding_cost)
# print(f"Economic Order Quantity (EOQ): {eoq_result:.2f}")

# # Calculate total cost associated with EOQ
# total_cost_result = calculate_total_cost(eoq_result, demand, ordering_cost, holding_cost)
# print(f"Total cost associated with EOQ: ${total_cost_result:.2f}")
